# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

team_stats24 = pd.read_csv('Team Stats 2024.csv')
dropodds = team_stats24.index % 2 != 0 
team_stats24 = team_stats24[~dropodds] # ~ create a boolean where True is the rows that we want to keep - dropping the odd numbered rows
team_stats24
# Out:
#         RK                    TEAM  CONF  ADJ. EFF. OFF.  ADJ. EFF. DEF.  \
# 0      1.0             Indiana St.   MVC           118.3           101.9
# 2      2.0              Wright St.  Horz           115.7           113.6
# 4      3.0             Creighton 3    BE           120.8            96.6
# 6      4.0      Eastern Washington  BSky           110.6           111.0
# 8      5.0              Kentucky 3   SEC           122.7           102.6
# ..     ...                     ...   ...             ...             ...
# 714  358.0              Lindenwood   OVC            91.5           113.5
# 716  359.0  Maryland Eastern Shore  MEAC            89.1           109.3
# 718  360.0  Mississippi Valley St.  SWAC            85.9           115.8
# 720  361.0              Coppin St.  MEAC            85.2           111.3
# 722  362.0             Alabama St.  SWAC            92.3           104.9
#
#      EFF. FG% OFF.  EFF. FG% DEF.  TURNOVER% OFF.  TURNOVER% DEF.  \
# 0             59.8           49.2            16.4            15.6
# 2             58.5           55.3            16.5            16.3
# 4             57.4           46.2            15.4            11.1
# 6             57.2           52.8            19.0            16.3
# 8             57.2           49.6            14.2            15.9
# ..             ...            ...             ...             ...
# 714           43.3           53.9            17.9            17.7
# 716           43.0           50.9            20.0            18.9
# 718           42.5           55.6            24.0            17.2
# 720           42.1           51.3            22.9            21.8
# 722           41.0           49.1            16.3            20.0
#
#      OFF. REB% OFF.  OFF. REB% DEF.  FT RATE OFF.  FT RATE DEF.  FT% OFF.  \
# 0              23.5            23.5          33.3          26.0      80.5
# 2              28.9            28.1          33.6          30.0      76.0
# 4              26.2            24.7          24.7          15.7      78.4
# 6              26.4            27.1          39.6          33.5      76.9
# 8              28.9            30.3          30.4          33.5      77.2
# ..              ...             ...           ...           ...       ...
# 714            23.6            28.7          38.3          40.2      72.8
# 716            28.8            33.7          32.7          37.8      71.3
# 718            27.9            35.7          33.0          41.6      65.8
# 720            27.0            38.6          31.1          38.3      72.6
# 722            31.7            29.1          28.5          43.4      71.9
#
#      FT% DEF.  2P% OFF.  2P% DEF.  3P% OFF.  3P% DEF.
# 0        74.4      62.5      48.7      38.1      33.4
# 2        72.0      58.8      55.0      38.4      37.1
# 4        78.5      59.7      45.7      36.6      31.7
# 6        74.2      58.7      51.0      36.8      36.9
# 8        71.5      54.7      49.4      40.9      33.2
# ..        ...       ...       ...       ...       ...
# 714      72.8      43.2      52.5      29.0      37.6
# 716      69.1      43.3      51.7      28.3      33.0
# 718      71.4      41.9      55.6      29.2      37.0
# 720      73.9      41.9      51.0      28.3      34.5
# 722      73.4      40.4      47.6      28.0      34.1
#
# [362 rows x 19 columns]

# %%
team_stats24.describe()
# Out:
#                RK  ADJ. EFF. OFF.  ADJ. EFF. DEF.  EFF. FG% OFF.  \
# count  362.000000      362.000000      362.000000     362.000000
# mean   181.500000      105.379006      105.379558      50.381768
# std    104.644637        7.539264        5.979181       3.028717
# min      1.000000       85.200000       86.500000      41.000000
# 25%     91.250000      100.000000      101.025000      48.300000
# 50%    181.500000      105.000000      105.600000      50.600000
# 75%    271.750000      110.275000      110.000000      52.200000
# max    362.000000      127.100000      121.000000      59.800000
#
#        EFF. FG% DEF.  TURNOVER% OFF.  TURNOVER% DEF.  OFF. REB% OFF.  \
# count     362.000000      362.000000      362.000000      362.000000
# mean       50.536464       17.133425       17.079006       28.829834
# std         2.373643        2.010131        2.279002        4.043509
# min        43.700000       12.000000       11.100000       17.300000
# 25%        49.000000       15.700000       15.725000       26.225000
# 50%        50.500000       17.000000       16.900000       28.600000
# 75%        52.200000       18.300000       18.375000       31.700000
# max        58.200000       24.000000       25.900000       42.200000
#
#        OFF. REB% DEF.  FT RATE OFF.  FT RATE DEF.    FT% OFF.    FT% DEF.  \
# count      362.000000    362.000000    362.000000  362.000000  362.000000
# mean        29.038122     32.904144     33.070442   71.855801   71.943094
# std          2.880046      4.722934      5.490549    3.565001    2.211120
# min         22.300000     21.400000     15.700000   59.800000   64.400000
# 25%         26.900000     29.325000     29.300000   69.900000   70.500000
# 50%         29.000000     32.700000     32.600000   72.100000   72.000000
# 75%         30.900000     36.175000     36.150000   74.175000   73.400000
# max         38.600000     50.000000     49.200000   80.800000   78.500000
#
#          2P% OFF.    2P% DEF.    3P% OFF.    3P% DEF.
# count  362.000000  362.000000  362.000000  362.000000
# mean    50.293370   50.390608   33.692541   33.852762
# std      3.359859    2.834975    2.501828    1.998048
# min     40.400000   42.900000   24.700000   27.900000
# 25%     48.100000   48.525000   32.100000   32.500000
# 50%     50.200000   50.600000   33.850000   33.900000
# 75%     52.275000   52.300000   35.500000   35.200000
# max     62.500000   59.000000   40.900000   40.300000

# %%
team_stats24.isnull().values.any()
# Out:
# False

# %%
team_stats24.duplicated().values.any()
# Out:
# False

# %%
plt.scatter(team_stats24["RK"], team_stats24["ADJ. EFF. OFF."])
plt.xlabel("Team Ranking")
plt.ylabel("Adjusted Offensive Efficiency")
plt.title("Summary of Team Offensive Eficiency")
# Out:
# Text(0.5, 1.0, 'Summary of Team Offensive Eficiency')

# %%
plt.scatter(team_stats24["RK"], team_stats24["ADJ. EFF. DEF."])
plt.xlabel("Team Ranking")
plt.ylabel("Adjusted Defensive Efficiency")
plt.title("Summary of Defensive Eficiency")
# Out:
# Text(0.5, 1.0, 'Summary of Defensive Eficiency')

# %%
plt.scatter(team_stats24["RK"], team_stats24["3P% OFF."])
plt.xlabel("Team Ranking")
plt.ylabel("3-Pointer Offensive Percentange")
plt.title("Summary of Offensive 3-Pointer's Made")
# Out:
# Text(0.5, 1.0, "Summary of Offensive 3-Pointer's Made")

# %%
team_stats17 = pd.read_csv('team_2017.csv', encoding = 'unicode_escape')
dropodds = team_stats17.index % 2 != 0 
team_stats17 = team_stats17[~dropodds] # ~ create a boolean where True is the rows that we want to keep - dropping the odd numbered rows
team_stats17
# Out:
#         RK              TEAM  CONF  ADJ. EFF. OFF.  ADJ. EFF. DEF.  \
# 0      1.0            UCLA 3   P12           123.5           100.5
# 2      2.0    Saint Mary's 7   WCC           118.9            94.7
# 4      3.0       Creighton 6    BE           115.2            96.2
# 6      4.0       Villanova 1    BE           122.9            93.5
# 8      5.0      Marquette 10    BE           122.5           102.9
# ..     ...               ...   ...             ...             ...
# 692  347.0              UTSA  CUSA            95.8           103.2
# 694  348.0        Morgan St.  MEAC            92.2           105.8
# 696  349.0       Chicago St.   WAC            92.2           111.5
# 698  350.0  UC Santa Barbara    BW            93.0           107.0
# 700  351.0    St. Francis NY   NEC            87.8           112.1
#
#      EFF. FG% OFF.  EFF. FG% DEF.  TURNOVER% OFF.  TURNOVER% DEF.  \
# 0             59.8           48.7            15.1            15.8
# 2             57.8           45.3            17.5            15.3
# 4             57.6           49.9            17.1            19.3
# 6             57.5           48.1            17.1            20.1
# 8             57.5           52.2            17.3            18.3
# ..             ...            ...             ...             ...
# 692           42.6           49.7            18.1            17.6
# 694           42.5           48.9            19.8            20.1
# 696           42.4           55.0            19.6            18.3
# 698           42.1           52.5            18.3            17.6
# 700           41.0           52.7            17.4            20.0
#
#      OFF. REB% OFF.  OFF. REB% DEF.  FT RATE OFF.  FT RATE DEF.  FT%OFF.  \
# 0              29.1            28.6          26.8          25.4     73.8
# 2              33.1            21.9          27.8          26.6     74.5
# 4              24.2            29.6          27.9          29.3     68.3
# 6              30.2            27.8          35.0          22.1     79.0
# 8              27.1            29.2          31.0          35.7     78.1
# ..              ...             ...           ...           ...      ...
# 692            32.4            24.2          36.2          37.9     66.7
# 694            34.8            31.2          37.8          41.5     71.4
# 696            26.1            31.1          27.8          35.5     70.9
# 698            30.8            29.6          28.8          32.3     63.3
# 700            27.9            33.4          31.8          46.9     64.8
#
#      FT%DEF.  2P% OFF.  2P% DEF.  3P% OFF.  3P% DEF.
# 0       67.9      59.1      45.3      40.6      36.5
# 2       69.1      56.9      45.4      39.4      30.0
# 4       68.9      56.4      50.2      39.8      33.0
# 6       70.3      59.2      49.1      36.9      31.1
# 8       69.7      52.7      50.6      42.9      36.8
# ..       ...       ...       ...       ...       ...
# 692     67.7      43.7      48.4      26.7      34.8
# 694     65.6      42.0      51.7      29.2      28.9
# 696     70.3      40.7      55.7      30.4      36.1
# 698     69.6      41.7      53.2      28.5      34.4
# 700     68.1      40.1      52.2      28.2      36.0
#
# [351 rows x 19 columns]

# %%
team_stats17.describe()
# Out:
#                RK  ADJ. EFF. OFF.  ADJ. EFF. DEF.  EFF. FG% OFF.  \
# count  351.000000      351.000000      351.000000     351.000000
# mean   176.000000      104.694302      104.691453      50.382906
# std    101.469207        7.275043        6.528818       3.052586
# min      1.000000       84.900000       87.200000      41.000000
# 25%     88.500000       99.750000      100.350000      48.300000
# 50%    176.000000      103.900000      104.400000      50.500000
# 75%    263.500000      109.000000      109.000000      52.350000
# max    351.000000      127.400000      124.500000      59.800000
#
#        EFF. FG% DEF.  TURNOVER% OFF.  TURNOVER% DEF.  OFF. REB% OFF.  \
# count     351.000000      351.000000      351.000000      351.000000
# mean       50.574644       18.591738       18.541026       29.118803
# std         2.815591        1.891882        2.101026        4.092940
# min        41.100000       13.900000       13.800000       15.000000
# 25%        48.700000       17.400000       17.150000       26.750000
# 50%        50.600000       18.500000       18.500000       29.300000
# 75%        52.600000       19.800000       19.800000       31.600000
# max        57.900000       25.900000       27.600000       41.300000
#
#        OFF. REB% DEF.  FT RATE OFF.  FT RATE DEF.     FT%OFF.     FT%DEF.  \
# count      351.000000    351.000000    351.000000  351.000000  351.000000
# mean        29.297151     35.326781     35.640456   70.353561   70.437037
# std          2.867043      4.486433      5.796187    3.757976    2.244217
# min         21.700000     24.000000     22.100000   59.400000   63.700000
# 25%         27.300000     32.450000     31.900000   67.900000   68.900000
# 50%         29.300000     35.100000     35.100000   70.100000   70.500000
# 75%         31.250000     38.250000     39.550000   73.050000   72.050000
# max         37.600000     46.000000     58.500000   80.000000   76.600000
#
#          2P% OFF.    2P% DEF.    3P% OFF.    3P% DEF.
# count  351.000000  351.000000  351.000000  351.000000
# mean    49.284900   49.437892   34.862963   35.055271
# std      3.257997    3.251165    2.711340    2.383639
# min     40.100000   39.900000   26.700000   28.900000
# 25%     47.150000   47.300000   33.000000   33.450000
# 50%     49.200000   49.500000   34.800000   35.100000
# 75%     51.400000   51.850000   36.800000   36.500000
# max     60.900000   58.600000   42.900000   42.000000

# %%
team_stats17.duplicated().values.any()
# Out:
# False

# %%
team_stats17.isnull().values.any()
# Out:
# False

# %%
plt.scatter(team_stats17["RK"], team_stats17["TURNOVER% OFF."])
plt.xlabel("Team Ranking")
plt.ylabel("Offensive Turnover Percentage")
plt.title("Summary of Offensive Turnovers")
# Out:
# Text(0.5, 1.0, 'Summary of Offensive Turnovers')

# %%
plt.scatter(team_stats17["RK"], team_stats17["EFF. FG% DEF."])
plt.xlabel("Team Ranking")
plt.ylabel("Defensive Eficiency Feild Goal Percentage")
plt.title("Percentage of Points Blocked")
# Out:
# Text(0.5, 1.0, 'Percentage of Points Blocked')

# %%
plt.scatter(team_stats17["RK"], team_stats17["3P% DEF."])
plt.xlabel("Team Ranking")
plt.ylabel("3-Pointers Blocked Percentange")
plt.title("Percentage of 3 Pointers Blocked")
# Out:
# Text(0.5, 1.0, 'Percentage of 3 Pointers Blocked')

# %%
team_stats16 = pd.read_csv('team_2016.csv', encoding = 'unicode_escape')
dropodds = team_stats16.index % 2 != 0 
team_stats16 = team_stats16[~dropodds] # ~ create a boolean where True is the rows that we want to keep - dropping the odd numbered rows
team_stats16
# Out:
#         RK              TEAM  CONF  ADJ. EFF. OFF.  ADJ. EFF. DEF.  \
# 0      1.0         Indiana 5   B10           122.1            99.5
# 2      2.0           Belmont   OVC           114.5           110.3
# 4      3.0      Saint Mary's   WCC           118.6            99.6
# 6      4.0     North Florida  ASun           114.4           113.9
# 8      5.0        Iowa St. 4   B12           122.1           100.2
# ..     ...               ...   ...             ...             ...
# 692  347.0           Bradley   MVC            87.0           102.0
# 694  348.0        Quinnipiac  MAAC            92.6           103.2
# 696  349.0       Chicago St.   WAC            91.8           113.5
# 698  350.0  Prairie View A&M  SWAC            89.4           107.8
# 700  351.0  Illinois Chicago  Horz            90.5           106.8
#
#      EFF. FG% OFF.  EFF. FG% DEF.  TURNOVER% OFF.  TURNOVER% DEF.  \
# 0             58.7           49.8            19.6            18.9
# 2             58.6           50.8            19.3            16.5
# 4             58.4           46.2            15.4            15.5
# 6             57.9           51.8            15.3            14.4
# 8             57.1           49.8            15.7            16.8
# ..             ...            ...             ...             ...
# 692           43.0           49.7            25.4            17.0
# 694           42.8           46.5            21.7            17.4
# 696           42.6           54.5            20.4            19.0
# 698           41.8           50.7            21.8            23.4
# 700           41.5           49.3            21.1            15.7
#
#      OFF. REB% OFF.  OFF. REB% DEF.  FT RATE OFF.  FT RATE DEF.  FT% OFF.  \
# 0              37.2            29.2          33.9          30.2      73.1
# 2              26.4            30.9          34.5          37.1      72.8
# 4              29.8            26.7          29.0          24.1      68.8
# 6              24.1            33.4          28.7          27.1      72.6
# 8              26.2            30.1          26.1          24.9      70.2
# ..              ...             ...           ...           ...       ...
# 692            24.9            26.7          38.3          52.2      67.0
# 694            38.4            29.3          28.0          40.1      64.7
# 696            29.5            33.4          28.1          43.6      66.1
# 698            30.7            36.3          36.4          47.4      68.6
# 700            31.9            30.7          43.2          39.6      61.9
#
#      FT% DEF.  2P% OFF.  2P% DEF.  3P% OFF.  3P% DEF.
# 0        68.1      56.1      49.0      41.6      34.3
# 2        72.1      62.6      49.5      36.4      35.4
# 4        68.0      56.4      44.8      41.0      32.7
# 6        66.8      54.7      51.8      40.9      34.6
# 8        68.8      56.7      49.5      38.7      33.5
# ..        ...       ...       ...       ...       ...
# 692      66.4      43.9      48.7      27.7      34.5
# 694      70.9      38.3      46.5      34.1      31.0
# 696      68.7      40.9      51.8      30.1      38.7
# 698      69.8      42.1      53.0      27.3      30.6
# 700      71.3      40.3      46.6      30.4      36.4
#
# [351 rows x 19 columns]

# %%
team_stats16.describe()
# Out:
#                RK  ADJ. EFF. OFF.  ADJ. EFF. DEF.  EFF. FG% OFF.  \
# count  351.000000      351.000000      351.000000     351.000000
# mean   176.000000      104.818519      104.820798      49.777493
# std    101.469207        7.397515        6.254036       3.029056
# min      1.000000       83.800000       89.000000      41.500000
# 25%     88.500000      100.050000      100.200000      47.700000
# 50%    176.000000      104.200000      104.900000      49.800000
# 75%    263.500000      109.900000      109.350000      51.700000
# max    351.000000      124.300000      119.200000      58.700000
#
#        EFF. FG% DEF.  TURNOVER% OFF.  TURNOVER% DEF.  OFF. REB% OFF.  \
# count     351.000000      351.000000      351.000000      351.000000
# mean       49.969801       18.183761       18.119943       29.618803
# std         2.687059        1.898087        2.084939        4.111467
# min        42.500000       13.600000       10.200000       17.700000
# 25%        48.150000       16.800000       16.700000       26.950000
# 50%        49.900000       18.100000       18.100000       29.600000
# 75%        51.700000       19.400000       19.400000       32.200000
# max        59.000000       25.400000       25.900000       42.000000
#
#        OFF. REB% DEF.  FT RATE OFF.  FT RATE DEF.   FT% OFF.    FT% DEF.  \
# count      351.000000    351.000000    351.000000  351.00000  351.000000
# mean        29.821083     36.637892     36.936467   69.88604   69.965812
# std          2.874868      4.607071      5.884574    3.44323    2.283925
# min         21.700000     25.500000     23.000000   58.90000   62.700000
# 25%         27.900000     33.300000     32.950000   67.60000   68.300000
# 50%         29.800000     36.800000     37.100000   69.70000   70.100000
# 75%         31.550000     40.200000     40.600000   72.35000   71.600000
# max         38.800000     49.400000     55.300000   79.30000   75.900000
#
#          2P% OFF.    2P% DEF.    3P% OFF.    3P% DEF.
# count  351.000000  351.000000  351.000000  351.000000
# mean    48.662963   48.822792   34.537892   34.729630
# std      3.255298    3.121857    2.804051    2.324977
# min     38.300000   41.300000   27.300000   28.700000
# 25%     46.300000   46.650000   32.600000   33.100000
# 50%     48.700000   48.900000   34.500000   34.800000
# 75%     50.700000   51.050000   36.400000   36.350000
# max     62.600000   59.800000   43.400000   42.200000

# %%
team_stats16.duplicated().values.any()
# Out:
# False

# %%
team_stats16.isnull().values.any()
# Out:
# False

# %%
plt.scatter(team_stats16["RK"], team_stats16["TURNOVER% DEF."])
plt.xlabel("Team Ranking")
plt.ylabel("Defensive Turnover Percentage")
plt.title("Summary of Defensive Turnovers")
# Out:
# Text(0.5, 1.0, 'Summary of Defensive Turnovers')

# %%
plt.scatter(team_stats16["RK"], team_stats16["OFF. REB% OFF."])
plt.xlabel("Team Ranking")
plt.ylabel("Offensive Rebound Percentage")
plt.title("Summary of Offensive Rebounds")
# Out:
# Text(0.5, 1.0, 'Summary of Offensive Rebounds')

# %%
plt.scatter(team_stats16["RK"], team_stats16["2P% OFF."])
plt.xlabel("Team Ranking")
plt.ylabel("")
plt.title("")

# %%
team_stats09 = pd.read_csv('team_2009.csv', encoding = 'unicode_escape')
dropodds = team_stats09.index % 2 != 0 
team_stats09 = team_stats09[~dropodds] # ~ create a boolean where True is the rows that we want to keep - dropping the odd numbered rows
team_stats09
# Out:
#         RK                    TEAM  CONF  ADJ. EFF. OFF.  ADJ. EFF. DEF.  \
# 0      1.0                  Denver    SB           101.0           104.2
# 2      2.0           Arizona St. 6   P10           118.0            94.6
# 4      3.0        Eastern Kentucky   OVC           111.5           111.7
# 6      4.0             Utah St. 11   WAC           116.1           102.0
# 8      5.0                  UCLA 6   P10           120.0            95.0
# ..     ...                     ...   ...             ...             ...
# 678  340.0  North Carolina Central   ind            85.2           113.4
# 680  341.0                  Drexel   CAA            97.8            96.3
# 682  342.0                 Hampton  MEAC            85.1            94.6
# 684  343.0        Loyola Marymount   WCC            89.7           106.0
# 686  344.0                    NJIT   ind            73.2           106.1
#
#      EFF. FG% OFF.  EFF. FG% DEF.  TURNOVER% OFF.  TURNOVER% DEF.  \
# 0             57.0           49.4            22.1            22.2
# 2             56.4           47.0            18.6            19.5
# 4             56.2           53.0            18.2            22.8
# 6             55.7           47.3            18.2            17.0
# 8             55.7           49.8            19.0            23.9
# ..             ...            ...             ...             ...
# 678           42.0           55.8            24.2            23.1
# 680           41.9           43.6            19.8            18.1
# 682           41.9           44.7            25.4            26.3
# 684           39.9           54.3            22.2            21.6
# 686           38.5           49.1            27.4            21.6
#
#      OFF. REB% OFF.  OFF. REB% DEF.  FT RATE OFF.  FT RATE DEF.  FT% OFF.  \
# 0              18.8            33.0          36.1          49.3      73.8
# 2              29.1            30.0          38.7          30.9      73.7
# 4              31.5            40.6          28.4          31.4      70.0
# 6              36.0            27.9          37.6          30.4      74.5
# 8              36.3            31.3          31.2          35.6      72.4
# ..              ...             ...           ...           ...       ...
# 678            27.8            40.6          30.8          41.2      67.6
# 680            39.5            32.0          38.8          38.3      67.9
# 682            36.1            36.2          37.6          35.4      66.0
# 684            31.3            37.6          34.2          34.2      68.5
# 686            29.3            33.0          30.6          45.0      63.1
#
#      FT% DEF.  2P% OFF.  2P% DEF.  3P% OFF.  3P% DEF.
# 0        71.4      57.5      50.0      37.7      31.9
# 2        73.8      57.1      46.5      37.0      31.9
# 4        68.7      52.1      52.5      40.6      35.8
# 6        74.5      54.0      44.3      39.5      36.3
# 8        69.6      53.5      48.0      39.9      36.1
# ..        ...       ...       ...       ...       ...
# 678      67.7      40.5      57.8      30.2      34.2
# 680      67.5      40.7      41.5      29.8      33.3
# 682      65.8      43.2      43.8      26.4      30.9
# 684      68.6      38.6      51.1      28.4      39.5
# 686      67.9      39.3      45.2      24.8      37.7
#
# [344 rows x 19 columns]
